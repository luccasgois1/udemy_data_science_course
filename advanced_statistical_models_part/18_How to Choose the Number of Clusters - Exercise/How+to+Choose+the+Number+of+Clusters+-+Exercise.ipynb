# %% [markdown]
# # How to Choose the Number of Clusters

# %% [markdown]
# Using the same code as in the previous exercise, find the WCSS for clustering solutions with 1 to 10 clusters (you can try with more if you wish).
#
# Find the most suitable solutions, run them and compare the results.

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sms
sms.set()

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Countries_exercise.csv'</i>.

# %%
pathfile = 'Countries_exercise.csv'
data = pd.read_csv(pathfile)
data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %%
lat = data['Latitude']
lon = data['Longitude']
plt.scatter(lon,lat)
plt.ylim([-90,90])
plt.xlim([-180, 180])
plt.show()

# %% [markdown]
# ## Select the features

# %% [markdown]
# Make sure to select the appropriate features since we are no longer using the categorical variable for our clustering but rather <i>'Longitude'</i> and <i>'Laditude'</i>.

# %%
x = data[['Longitude','Latitude']]
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %% [markdown]
# ## Clustering

# %% [markdown]
# Use 4 clusters initially.

# %%
kmeans = KMeans(4)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=4)

# %% [markdown]
# ### Clustering results

# %%
data_with_cluster = data.copy()
data_with_cluster['Clusters'] = kmeans.predict(x)

# %%
data_with_cluster
# Out:
#              name   Longitude   Latitude  Clusters
# 0           Aruba  -69.982677  12.520880         1
# 1     Afghanistan   66.004734  33.835231         0
# 2          Angola   17.537368 -12.293361         0
# 3        Anguilla  -63.064989  18.223959         1
# 4         Albania   20.049834  41.142450         2
# ..            ...         ...        ...       ...
# 236         Samoa -172.164851 -13.753243         1
# 237         Yemen   47.586762  15.909280         0
# 238  South Africa   25.083901 -29.000341         0
# 239        Zambia   27.774759 -13.458242         0
# 240      Zimbabwe   29.851441 -19.004204         0
#
# [241 rows x 4 columns]

# %% [markdown]
# Plot the data once again but separate the data by the clusters we defined.

# %% [markdown]
# ## Plot the data

# %%
lat = data_with_cluster['Latitude']
lon =data_with_cluster['Longitude']
cluster_plot = data_with_cluster['Clusters']

plt.scatter(lon,lat,c=cluster_plot,cmap='rainbow')
plt.ylim([-90,90])
plt.xlim([-180, 180])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## Selecting the number of clusters

# %% [markdown]
# ### WCSS

# %% [markdown]
# Use the ingerated <i>sklearn</i> method <i> 'inertia_' </i>.

# %%
kmeans.inertia_
# Out:
# 256573.08675934304

# %% [markdown]
# Write a loop that calculates and saves the WCSS for any number of clusters from 1 up to 10 (or more if you wish).

# %%
#list_wcss = []
#for i in range(1,11):
#    kmean_i = KMeans(i)
#    kmean_i.fit(x)
#    wcss = kmean_i.inertia_
#    list_wcss.append(wcss)
list_wcss = [KMeans(i).fit(x).inertia_ for i in range(1,11)]
# Out:
# C:\Users\Luccas\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
print(list_wcss)
# Out:
# [1413859.67983443  657012.07975863  325235.52237056  256590.58575406
#   192212.48189497  151410.08098853  126799.10093908  102954.3664203
#    84945.1946124    76499.7725864 ]

# %% [markdown]
# ### The Elbow Method

# %%
plt.plot(range(1,11), list_wcss,'.-')
plt.xticks(range(1,11))
plt.ticklabel_format(style='plain')
plt.show()

# %% [markdown]
# Based on the Elbow Curve, plot several graphs with the appropriate amounts of clusters you believe would best fit the data.

# %% [markdown]
# Compare the scatter plots to determine which one to use in our further analysis.

# %% [markdown]
# <i>Hint: we already created the scatter plot for 4 clusters, so we only have to slightly alter our code.</i>

# %%
kmeans = KMeans(2)
kmeans.fit(x)
lat = data_with_cluster['Latitude']
lon =data_with_cluster['Longitude']
cluster_plot = kmeans.predict(x)

plt.scatter(lon,lat,c=cluster_plot,cmap='rainbow')
plt.title('2 - Cluster')
plt.ylim([-90,90])
plt.xlim([-180, 180])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
kmeans = KMeans(3)
kmeans.fit(x)
lat = data_with_cluster['Latitude']
lon =data_with_cluster['Longitude']
cluster_plot = kmeans.predict(x)

plt.scatter(lon,lat,c=cluster_plot,cmap='rainbow')
plt.title('3 - Cluster')
plt.ylim([-90,90])
plt.xlim([-180, 180])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
